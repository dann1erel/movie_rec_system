# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\movie_rec_system\data\kinopoisk-top250.csv', index_col='rating')
df.head(5)
# Out:
#                      movie  year  country  rating_ball  \
# rating
# 0       Побег из Шоушенка   1994      США        9.111
# 1            Зеленая миля   1999      США        9.062
# 2            Форрест Гамп   1994      США        8.913
# 3         Список Шиндлера   1993      США        8.817
# 4                     1+1   2011  Франция        8.807
#
#                                                  overview  \
# rating
# 0       Бухгалтер Энди Дюфрейн обвинён в убийстве собс...
# 1       Пол Эджкомб — начальник блока смертников в тюр...
# 2       От лица главного героя Форреста Гампа; слабоум...
# 3       Фильм рассказывает реальную историю загадочног...
# 4       Пострадав в результате несчастного случая; бог...
#
#                              director  \
# rating
# 0                      Фрэнк Дарабонт
# 1                      Фрэнк Дарабонт
# 2                      Роберт Земекис
# 3                     Стивен Спилберг
# 4        Оливье Накаш;  Эрик Толедано
#
# ...

# %%
df['movie'][:5]
# Out:
# rating
# 0    Побег из Шоушенка
# 1         Зеленая миля
# 2         Форрест Гамп
# 3      Список Шиндлера
# 4                  1+1
# Name: movie, dtype: object
